# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df=pd.read_excel("C:/Users/Najeeb ULLAH/Downloads/Apple historical_data (1).xlsx")

# %%
df
# Out:
#                             Date        Open        High         Low  \
# 0      1980-12-12 00:00:00-05:00    0.098834    0.099264    0.098834
# 1      1980-12-15 00:00:00-05:00    0.094108    0.094108    0.093678
# 2      1980-12-16 00:00:00-05:00    0.087232    0.087232    0.086802
# 3      1980-12-17 00:00:00-05:00    0.088951    0.089381    0.088951
# 4      1980-12-18 00:00:00-05:00    0.091530    0.091959    0.091530
# ...                          ...         ...         ...         ...
# 11089  2024-12-09 00:00:00-05:00  241.830002  247.240005  241.750000
# 11090  2024-12-10 00:00:00-05:00  246.889999  248.210007  245.339996
# 11091  2024-12-11 00:00:00-05:00  247.960007  250.800003  246.259995
# 11092  2024-12-12 00:00:00-05:00  246.889999  248.740005  245.679993
# 11093  2024-12-13 00:00:00-05:00  247.820007  249.289993  246.240005
#
#             Close
# 0        0.098834
# 1        0.093678
# 2        0.086802
# 3        0.088951
# 4        0.091530
# ...           ...
# ...

# %%
x=df[['Close','High','Low']]

# %%
x
# Out:
#             Close        High         Low
# 0        0.098834    0.099264    0.098834
# 1        0.093678    0.094108    0.093678
# 2        0.086802    0.087232    0.086802
# 3        0.088951    0.089381    0.088951
# 4        0.091530    0.091959    0.091530
# ...           ...         ...         ...
# 11089  246.750000  247.240005  241.750000
# 11090  247.770004  248.210007  245.339996
# 11091  246.490005  250.800003  246.259995
# 11092  247.960007  248.740005  245.679993
# 11093  248.130005  249.289993  246.240005
#
# [11094 rows x 3 columns]

# %%
y=df['Close']

# %%
y
# Out:
# 0          0.098834
# 1          0.093678
# 2          0.086802
# 3          0.088951
# 4          0.091530
#             ...
# 11089    246.750000
# 11090    247.770004
# 11091    246.490005
# 11092    247.960007
# 11093    248.130005
# Name: Close, Length: 11094, dtype: float64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
LinearRegression=LinearRegression()

# %%
LinearRegression.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predict=LinearRegression.predict(xtest)

# %%
mean_squared_error(ytest,predict)
# Out:
# 8.04556784573107e-28

# %%
model=SGDRegressor(max_iter=1000,alpha=0.001)

# %%
model.fit(xtrain,ytrain)
# Out:
# SGDRegressor(alpha=0.001)

# %%
predict=model.predict(xtest)

# %%
mean_squared_error(ytest,predict)
# Out:
# 3.559993236863772e+25
